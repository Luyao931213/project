# %%
# !pip install ts2vg
# !pip install igraph
#!pip install pycairo
# !pip install cairocffi
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 88 kB 3.6 MB/s
# ...
#   Created wheel for cairocffi: filename=cairocffi-1.3.0-py3-none-any.whl size=89667 sha256=8f2bb6b41f6e6a3aa9fb60f9e79b4fdfda3fd6064f879012a55f4ec973b621d5
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/e1/5c8a9692a27f639a07c949044bec943f26c81cd53d3805319f
# Successfully built cairocffi
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read data
#
#
# > Data should be in google drive if using google colab. If using local Jupyter Notebook, follow the below data folder structure and change source to the root folder
#
#
# > - data
#  -  subject_1
#    -  acc_walking_chest.csv
#     -  acc_running_chest.csv
#     - ...
#   -  subject_2
#     -  acc_walking_chest.csv
#     - ...
#   - ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root = 'drive/MyDrive/'
subject1_running = pd.read_csv(root + 'data/subject_1/acc_running_chest.csv')
subject1_walking = pd.read_csv(root + 'data/subject_1/acc_walking_chest.csv')
subject1_climbdown = pd.read_csv(root + 'data/subject_1/acc_climbingdown_chest.csv')
subject1_climbup = pd.read_csv(root + 'data/subject_1/acc_climbingup_chest.csv')

subject2_running = pd.read_csv(root + 'data/subject_2/acc_running_chest.csv')
subject2_walking = pd.read_csv(root + 'data/subject_2/acc_walking_chest.csv')
subject2_climbdown = pd.read_csv(root + 'data/subject_2/acc_climbingdown_chest.csv')
subject2_climbup = pd.read_csv(root + 'data/subject_2/acc_climbingup_chest.csv')

subject3_running = pd.read_csv(root + 'data/subject_3/acc_running_chest.csv')
subject3_walking = pd.read_csv(root + 'data/subject_3/acc_walking_chest.csv')
subject3_climbdown = pd.read_csv(root + 'data/subject_3/acc_climbingdown_chest.csv')
subject3_climbup = pd.read_csv(root + 'data/subject_3/acc_climbingup_chest.csv')

subject4_running = pd.read_csv(root + 'data/subject_4/acc_running_chest.csv')
subject4_walking = pd.read_csv(root + 'data/subject_4/acc_walking_chest.csv')
subject4_climbdown = pd.read_csv(root + 'data/subject_4/acc_climbingdown_chest.csv')
subject4_climbup = pd.read_csv(root + 'data/subject_4/acc_climbingup_chest.csv')

subject5_running = pd.read_csv(root + 'data/subject_5/acc_running_chest.csv')
subject5_walking = pd.read_csv(root + 'data/subject_5/acc_walking_chest.csv')
subject5_climbdown = pd.read_csv(root + 'data/subject_5/acc_climbingdown_chest.csv')
subject5_climbup = pd.read_csv(root + 'data/subject_5/acc_climbingup_chest.csv')

subject6_running = pd.read_csv(root + 'data/subject_6/acc_running_chest.csv')
subject6_walking = pd.read_csv(root + 'data/subject_6/acc_walking_chest.csv')
subject6_climbdown = pd.read_csv(root + 'data/subject_6/acc_climbingdown_chest.csv')
subject6_climbup = pd.read_csv(root + 'data/subject_6/acc_climbingup_chest.csv')

subject7_running = pd.read_csv(root + 'data/subject_7/acc_running_chest.csv')
subject7_walking = pd.read_csv(root + 'data/subject_7/acc_walking_chest.csv')
subject7_climbdown = pd.read_csv(root + 'data/subject_7/acc_climbingdown_chest.csv')
subject7_climbup = pd.read_csv(root + 'data/subject_7/acc_climbingup_chest.csv')

subject8_running = pd.read_csv(root + 'data/subject_8/acc_running_chest.csv')
subject8_walking = pd.read_csv(root + 'data/subject_8/acc_walking_chest.csv')
subject8_climbdown = pd.read_csv(root + 'data/subject_8/acc_climbingdown_chest.csv')
subject8_climbup = pd.read_csv(root + 'data/subject_8/acc_climbingup_chest.csv')

subject9_running = pd.read_csv(root + 'data/subject_9/acc_running_chest.csv')
subject9_walking = pd.read_csv(root + 'data/subject_9/acc_walking_chest.csv')
subject9_climbdown = pd.read_csv(root + 'data/subject_9/acc_climbingdown_chest.csv')
subject9_climbup = pd.read_csv(root + 'data/subject_9/acc_climbingup_chest.csv')

subject10_running = pd.read_csv(root + 'data/subject_10/acc_running_chest.csv')
subject10_walking = pd.read_csv(root + 'data/subject_10/acc_walking_chest.csv')
subject10_climbdown = pd.read_csv(root + 'data/subject_10/acc_climbingdown_chest.csv')
subject10_climbup = pd.read_csv(root + 'data/subject_10/acc_climbingup_chest.csv')

subject11_running = pd.read_csv(root + 'data/subject_11/acc_running_chest.csv')
subject11_walking = pd.read_csv(root + 'data/subject_11/acc_walking_chest.csv')
subject11_climbdown = pd.read_csv(root + 'data/subject_11/acc_climbingdown_chest.csv')
subject11_climbup = pd.read_csv(root + 'data/subject_11/acc_climbingup_chest.csv')

subject12_running = pd.read_csv(root + 'data/subject_12/acc_running_chest.csv')
subject12_walking = pd.read_csv(root + 'data/subject_12/acc_walking_chest.csv')
subject12_climbdown = pd.read_csv(root + 'data/subject_12/acc_climbingdown_chest.csv')
subject12_climbup = pd.read_csv(root + 'data/subject_12/acc_climbingup_chest.csv')

subject13_running = pd.read_csv(root + 'data/subject_13/acc_running_chest.csv')
subject13_walking = pd.read_csv(root + 'data/subject_13/acc_walking_chest.csv')
subject13_climbdown = pd.read_csv(root + 'data/subject_13/acc_climbingdown_chest.csv')
subject13_climbup = pd.read_csv(root + 'data/subject_13/acc_climbingup_chest.csv')

subject14_running = pd.read_csv(root + 'data/subject_14/acc_running_chest.csv')
subject14_walking = pd.read_csv(root + 'data/subject_14/acc_walking_chest.csv')
subject14_climbdown = pd.read_csv(root + 'data/subject_14/acc_climbingdown_chest.csv')
subject14_climbup = pd.read_csv(root + 'data/subject_14/acc_climbingup_chest.csv')

subject15_running = pd.read_csv(root + 'data/subject_15/acc_running_chest.csv')
subject15_walking = pd.read_csv(root + 'data/subject_15/acc_walking_chest.csv')
subject15_climbdown = pd.read_csv(root + 'data/subject_15/acc_climbingdown_chest.csv')
subject15_climbup = pd.read_csv(root + 'data/subject_15/acc_climbingup_chest.csv')

# %% [markdown]
# ## Concatenate to form data frames per subject

# %%
subject1_walking['Activity'] = 'Walking'
subject1_running['Activity'] = 'Running'
subject1_climbup['Activity'] = 'Climbing Up'
subject1_climbdown['Activity'] = 'Climbing Down'
subject1_df = pd.concat([subject1_walking, subject1_running, subject1_climbup, subject1_climbdown], ignore_index=True)

subject2_walking['Activity'] = 'Walking'
subject2_running['Activity'] = 'Running'
subject2_climbup['Activity'] = 'Climbing Up'
subject2_climbdown['Activity'] = 'Climbing Down'
subject2_df = pd.concat([subject2_walking, subject2_running, subject2_climbup, subject2_climbdown], ignore_index=True)

subject3_walking['Activity'] = 'Walking'
subject3_running['Activity'] = 'Running'
subject3_climbup['Activity'] = 'Climbing Up'
subject3_climbdown['Activity'] = 'Climbing Down'
subject3_df = pd.concat([subject3_walking, subject3_running, subject3_climbup, subject3_climbdown], ignore_index=True)

subject4_walking['Activity'] = 'Walking'
subject4_running['Activity'] = 'Running'
subject4_climbup['Activity'] = 'Climbing Up'
subject4_climbdown['Activity'] = 'Climbing Down'
subject4_df = pd.concat([subject4_walking, subject4_running, subject4_climbup, subject4_climbdown], ignore_index=True)

subject5_walking['Activity'] = 'Walking'
subject5_running['Activity'] = 'Running'
subject5_climbup['Activity'] = 'Climbing Up'
subject5_climbdown['Activity'] = 'Climbing Down'
subject5_df = pd.concat([subject5_walking, subject5_running, subject5_climbup, subject5_climbdown], ignore_index=True)

subject6_walking['Activity'] = 'Walking'
subject6_running['Activity'] = 'Running'
subject6_climbup['Activity'] = 'Climbing Up'
subject6_climbdown['Activity'] = 'Climbing Down'
subject6_df = pd.concat([subject6_walking, subject6_running, subject6_climbup, subject6_climbdown], ignore_index=True)

subject7_walking['Activity'] = 'Walking'
subject7_running['Activity'] = 'Running'
subject7_climbup['Activity'] = 'Climbing Up'
subject7_climbdown['Activity'] = 'Climbing Down'
subject7_df = pd.concat([subject7_walking, subject7_running, subject7_climbup, subject7_climbdown], ignore_index=True)

subject8_walking['Activity'] = 'Walking'
subject8_running['Activity'] = 'Running'
subject8_climbup['Activity'] = 'Climbing Up'
subject8_climbdown['Activity'] = 'Climbing Down'
subject8_df = pd.concat([subject8_walking, subject8_running, subject8_climbup, subject8_climbdown], ignore_index=True)

subject9_walking['Activity'] = 'Walking'
subject9_running['Activity'] = 'Running'
subject9_climbup['Activity'] = 'Climbing Up'
subject9_climbdown['Activity'] = 'Climbing Down'
subject9_df = pd.concat([subject9_walking, subject9_running, subject9_climbup, subject9_climbdown], ignore_index=True)

subject10_walking['Activity'] = 'Walking'
subject10_running['Activity'] = 'Running'
subject10_climbup['Activity'] = 'Climbing Up'
subject10_climbdown['Activity'] = 'Climbing Down'
subject10_df = pd.concat([subject10_walking, subject10_running, subject10_climbup, subject10_climbdown], ignore_index=True)

subject11_walking['Activity'] = 'Walking'
subject11_running['Activity'] = 'Running'
subject11_climbup['Activity'] = 'Climbing Up'
subject11_climbdown['Activity'] = 'Climbing Down'
subject11_df = pd.concat([subject11_walking, subject11_running, subject11_climbup, subject11_climbdown], ignore_index=True)

subject12_walking['Activity'] = 'Walking'
subject12_running['Activity'] = 'Running'
subject12_climbup['Activity'] = 'Climbing Up'
subject12_climbdown['Activity'] = 'Climbing Down'
subject12_df = pd.concat([subject12_walking, subject12_running, subject12_climbup, subject12_climbdown], ignore_index=True)

subject13_walking['Activity'] = 'Walking'
subject13_running['Activity'] = 'Running'
subject13_climbup['Activity'] = 'Climbing Up'
subject13_climbdown['Activity'] = 'Climbing Down'
subject13_df = pd.concat([subject13_walking, subject13_running, subject13_climbup, subject13_climbdown], ignore_index=True)

subject14_walking['Activity'] = 'Walking'
subject14_running['Activity'] = 'Running'
subject14_climbup['Activity'] = 'Climbing Up'
subject14_climbdown['Activity'] = 'Climbing Down'
subject14_df = pd.concat([subject14_walking, subject14_running, subject14_climbup, subject14_climbdown], ignore_index=True)

subject15_walking['Activity'] = 'Walking'
subject15_running['Activity'] = 'Running'
subject15_climbup['Activity'] = 'Climbing Up'
subject15_climbdown['Activity'] = 'Climbing Down'
subject15_df = pd.concat([subject15_walking, subject15_running, subject15_climbup, subject15_climbdown], ignore_index=True)

# %% [markdown]
# # Task 1

# %% [markdown]
# ## Natural Visibility Graph and Horizontal Visibility Graph

# %% [markdown]
# ### Function to generate output table

# %%
from ts2vg import NaturalVG
from ts2vg import HorizontalVG


#Function to create result dataframe for a subject and activity
def create_graph_results(df, subject):
  rows_list = []
  for activity in ['Running', 'Walking', 'Climbing Up', 'Climbing Down']:
    for attr in ['attr_x', 'attr_y', 'attr_z']:
      g = NaturalVG()
      df_sub = df[df['Activity'] == activity][attr][1000:2024]
      g.build(df_sub)
      ig_g = g.as_igraph()
      dict1 = {}
      dict1['Method'] = "NVG"
      dict1['Subject'] = subject
      dict1['Accelerometer axis'] = attr.split(sep='_')[1].upper()
      dict1['Average Degree'] = np.mean(ig_g.degree())
      dict1["Network Diameter"] = ig_g.diameter()
      dict1["Average Path Length"] = ig_g.average_path_length()
      dict1["Activity"] = activity
      rows_list.append(dict1)

      g = HorizontalVG()
      g.build(df_sub)
      ig_g = g.as_igraph()
      dict1 = {}
      dict1['Method'] = "HVG"
      dict1['Subject'] = subject
      dict1['Accelerometer axis'] = attr.split(sep='_')[1].upper()
      dict1['Average Degree'] = np.mean(ig_g.degree())
      dict1["Network Diameter"] = ig_g.diameter()
      dict1["Average Path Length"] = ig_g.average_path_length()
      dict1["Activity"] = activity
      rows_list.append(dict1)

  result_df = pd.DataFrame(rows_list)
  return result_df

# %% [markdown]
# ### Calculating required metrics for all data

# %%
subject1_g_df = create_graph_results(subject1_df, 1)
subject2_g_df = create_graph_results(subject2_df, 2)
subject3_g_df = create_graph_results(subject3_df, 3)
subject4_g_df = create_graph_results(subject4_df, 4)
subject5_g_df = create_graph_results(subject5_df, 5)
subject6_g_df = create_graph_results(subject6_df, 6)
subject7_g_df = create_graph_results(subject7_df, 7)
subject8_g_df = create_graph_results(subject8_df, 8)
subject9_g_df = create_graph_results(subject9_df, 9)
subject10_g_df = create_graph_results(subject10_df, 10)
subject11_g_df = create_graph_results(subject11_df, 11)
subject12_g_df = create_graph_results(subject12_df, 12)
subject13_g_df = create_graph_results(subject13_df, 13)
subject14_g_df = create_graph_results(subject14_df, 14)
subject15_g_df = create_graph_results(subject15_df, 15)

final_results = pd.concat([subject1_g_df, subject2_g_df, subject3_g_df, subject4_g_df, subject5_g_df,
                           subject6_g_df, subject7_g_df, subject8_g_df, subject9_g_df, subject10_g_df,
                           subject11_g_df, subject12_g_df, subject13_g_df, subject14_g_df, subject15_g_df])
final_results
# Out:
#    Method  Subject  ... Average Path Length       Activity
# 0     NVG        1  ...            4.307645        Running
# 1     HVG        1  ...            7.543843        Running
# 2     NVG        1  ...           28.651949        Running
# 3     HVG        1  ...           31.634922        Running
# 4     NVG        1  ...            4.644369        Running
# ..    ...      ...  ...                 ...            ...
# 19    HVG       15  ...           13.926625  Climbing Down
# 20    NVG       15  ...            5.840334  Climbing Down
# 21    HVG       15  ...           13.582100  Climbing Down
# 22    NVG       15  ...            4.692059  Climbing Down
# 23    HVG       15  ...           11.783465  Climbing Down
#
# [360 rows x 7 columns]

# %% [markdown]
# ##Average degree vs Network diameter scatter plots

# %%
walking_running_df = final_results[final_results['Activity'].isin(['Walking', 'Running'])]
climbing_df = final_results[final_results['Activity'].isin(['Climbing Up', 'Climbing Down'])]

# %% [markdown]
# ## Average degree vs Network diameter (Walking and running)
#
#
# > We create a facet grid, to plot all 6 plots (3 accelerometer signals)

# %%
sns.set(font_scale = 1.2)
graph = sns.FacetGrid(walking_running_df, col ='Accelerometer axis', row ='Method',
                      height = 5, sharex=False , sharey=False)
graph.map_dataframe(sns.scatterplot, 'Average Degree', "Network Diameter",  
                    hue = 'Activity', s = 150).add_legend()

# %% [markdown]
# ## Average degree vs Network diameter (Climbing Up and Climbing Down)
#
#
# > We create a facet grid, to plot all 6 plots (3 accelerometer signals)

# %%
graph = sns.FacetGrid(climbing_df, col ='Accelerometer axis', row ='Method',
                      height = 5, sharex=False , sharey=False)
graph.map_dataframe(sns.scatterplot, 'Average Degree', "Network Diameter",  
                    hue = 'Activity', s = 150).add_legend()

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Helper Functions

# %%
def s_entropy(freq_list):
    ''' This function computes the shannon entropy of a given frequency distribution.
    USAGE: shannon_entropy(freq_list)
    ARGS: freq_list = Numeric vector representing the frequency distribution
    OUTPUT: A numeric value representing shannon's entropy'''
    freq_list = [element for element in freq_list if element != 0]
    sh_entropy = 0.0
    for freq in freq_list:
        sh_entropy += freq * np.log(freq)
    sh_entropy = -sh_entropy
    return(sh_entropy)

def ordinal_patterns(ts, embdim, embdelay):
    ''' This function computes the ordinal patterns of a time series for a given embedding dimension and embedding delay.
    USAGE: ordinal_patterns(ts, embdim, embdelay)
    ARGS: ts = Numeric vector representing the time series, embdim = embedding dimension (3<=embdim<=7 prefered range), embdelay =  embdding delay
    OUPTUT: A numeric vector representing frequencies of ordinal patterns'''
    m, t = embdim, embdelay
    x = ts if isinstance(ts, np.ndarray) else np.array(ts) 

    tmp = np.zeros((x.shape[0], m))
    for i in range(m):
        tmp[:, i] = np.roll(x, i*t)
    partition = tmp[(t*m-1):, :] 
    permutation = np.argsort(partition)
    idx = _hash(permutation)

    counts = np.zeros(np.math.factorial(m))
    for i in range(counts.shape[0]):
        counts[i] = (idx == i).sum()
    return list(counts[counts != 0].astype(int))

def _hash(x):
    m, n = x.shape
    if n == 1:
        return np.zeros(m)
    return np.sum(np.apply_along_axis(lambda y: y < x[:, 0], 0, x), axis=1) * np.math.factorial(n-1) + _hash(x[:, 1:]) 
    

def p_entropy(op):
    ordinal_pat = op
    max_entropy = np.log(len(ordinal_pat))
    p = np.divide(np.array(ordinal_pat), float(sum(ordinal_pat)))
    return(s_entropy(p)/max_entropy)

def complexity(op):
    ''' This function computes the complexity of a time series defined as: Comp_JS = Q_o * JSdivergence * pe
    Q_o = Normalizing constant
    JSdivergence = Jensen-Shannon divergence
    pe = permutation entopry
    ARGS: ordinal pattern'''
    pe = p_entropy(op)
    constant1 = (0.5+((1 - 0.5)/len(op)))* np.log(0.5+((1 - 0.5)/len(op)))
    constant2 = ((1 - 0.5)/len(op))*np.log((1 - 0.5)/len(op))*(len(op) - 1)
    constant3 = 0.5*np.log(len(op))
    Q_o = -1/(constant1+constant2+constant3)

    temp_op_prob = np.divide(op, sum(op))
    temp_op_prob2 = (0.5*temp_op_prob)+(0.5*(1/len(op)))
    JSdivergence = (s_entropy(temp_op_prob2) - 0.5 * s_entropy(temp_op_prob) - 0.5 * np.log(len(op)))
    Comp_JS = Q_o * JSdivergence * pe
    return(Comp_JS)

# %% [markdown]
# ## Calculate results

# %%
def create_permutation_entropy_complexity_df(df, subject_num):
  row_list = []
  for ax in ['attr_x', 'attr_y', 'attr_z']:
    for sig in [1024, 2048, 4096]:
      for dim in [3, 4, 5, 6]:
        for delay in [1, 2, 3]:
          for activity in ['Walking', 'Running', 'Climbing Up', 'Climbing Down']:

            dict1 = {}
            start = 1000
            end = start + sig
            df_sub = df[(df['Activity'] == activity)][ax]

            op = ordinal_patterns(df_sub[start:end], embdim = dim, embdelay = delay)

            dict1['Subject'] = subject_num
            dict1['Accelerometer Axis'] = ax.split(sep='_')[1].upper()
            dict1['Signal length'] = sig
            dict1['Dimension'] = dim
            dict1['Delay'] = delay
            dict1['Permutation Entropy'] = p_entropy(op)
            dict1['Complexity'] = complexity(op)
            dict1['Activity'] = activity

            row_list.append(dict1)
          
  result_df = pd.DataFrame(row_list)
  return result_df

# %%
subject1_pc_df = create_permutation_entropy_complexity_df(subject1_df, 1)
subject2_pc_df = create_permutation_entropy_complexity_df(subject2_df, 2)
subject3_pc_df = create_permutation_entropy_complexity_df(subject3_df, 3)
subject4_pc_df = create_permutation_entropy_complexity_df(subject4_df, 4)
subject5_pc_df = create_permutation_entropy_complexity_df(subject5_df, 5)
subject6_pc_df = create_permutation_entropy_complexity_df(subject6_df, 6)
subject7_pc_df = create_permutation_entropy_complexity_df(subject7_df, 7)
subject8_pc_df = create_permutation_entropy_complexity_df(subject8_df, 8)
subject9_pc_df = create_permutation_entropy_complexity_df(subject9_df, 9)
subject10_pc_df = create_permutation_entropy_complexity_df(subject10_df, 10)
subject11_pc_df = create_permutation_entropy_complexity_df(subject11_df, 11)
subject12_pc_df = create_permutation_entropy_complexity_df(subject12_df, 12)
subject13_pc_df = create_permutation_entropy_complexity_df(subject13_df, 13)
subject14_pc_df = create_permutation_entropy_complexity_df(subject14_df, 14)
subject15_pc_df = create_permutation_entropy_complexity_df(subject15_df, 15)

final_results = pd.concat([subject1_pc_df, subject2_pc_df, subject3_pc_df, subject4_pc_df, subject5_pc_df,
                           subject6_pc_df, subject7_pc_df, subject8_pc_df, subject9_pc_df, subject10_pc_df,
                           subject11_pc_df, subject12_pc_df, subject13_pc_df, subject14_pc_df, subject15_pc_df])
final_results
# Out:
#      Subject Accelerometer Axis  ...  Complexity       Activity
# 0          1                  X  ...    0.133484        Walking
# 1          1                  X  ...    0.086750        Running
# 2          1                  X  ...    0.151027    Climbing Up
# 3          1                  X  ...    0.181020  Climbing Down
# 4          1                  X  ...    0.035722        Walking
# ..       ...                ...  ...         ...            ...
# 427       15                  Z  ...    0.145734  Climbing Down
# 428       15                  Z  ...    0.182782        Walking
# 429       15                  Z  ...    0.177747        Running
# 430       15                  Z  ...    0.192064    Climbing Up
# 431       15                  Z  ...    0.088420  Climbing Down
#
# [6480 rows x 8 columns]

# %%
walking_running_df = final_results[(final_results['Activity'].isin(['Walking', 'Running']))].reset_index(drop = True)
climbing_df = final_results[final_results['Activity'].isin(['Climbing Up', 'Climbing Down'])].reset_index(drop = True)

# %% [markdown]
# ## Average degree vs Network diameter (Walking and running)
#
#
# > We create a facet grid, to plot all 12 plots (3 accelerometer signals)

# %% [markdown]
# ### Signal length = 1024, embedded delay = 1, embedded dimension = 3,4,5,6 and all accelerometer directions

# %%
df_running_sub = walking_running_df[(walking_running_df['Signal length'] == 4096) & (walking_running_df['Delay'] == 1)]
df_climbing_sub = climbing_df[(climbing_df['Signal length'] == 4096) & (climbing_df['Delay'] == 1)]

# %%
sns.set(font_scale = 1.2)
graph = sns.FacetGrid(df_running_sub, col ='Accelerometer Axis', row ='Dimension',
                      height = 5, sharex=False , sharey=False )
graph.map_dataframe(sns.scatterplot, 'Permutation Entropy', "Complexity",  
                    hue = 'Activity', s = 150).add_legend()

# %% [markdown]
# ## Average degree vs Network diameter (Climbing Up and Climbing Down)
#
#
# > We create a facet grid, to plot all 12 plots (3 accelerometer signals)

# %%
sns.set(font_scale = 1.2)
graph = sns.FacetGrid(df_climbing_sub, col ='Accelerometer Axis', row ='Dimension',
                      height = 5, sharex=False , sharey=False )
graph.map_dataframe(sns.scatterplot, 'Permutation Entropy', "Complexity",  
                    hue = 'Activity', s = 150).add_legend()
